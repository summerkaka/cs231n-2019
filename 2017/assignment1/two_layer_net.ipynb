# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.6802720710348014e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 0.018965419606062905

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W2 max relative error: 3.440708e-09
# b2 max relative error: 4.447625e-11
# W1 max relative error: 3.561318e-09
# b1 max relative error: 2.738421e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.017143643532923747

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302762
# iteration 100 / 1000: loss 2.302358
# iteration 200 / 1000: loss 2.297404
# iteration 300 / 1000: loss 2.258897
# iteration 400 / 1000: loss 2.202975
# iteration 500 / 1000: loss 2.116816
# iteration 600 / 1000: loss 2.049789
# iteration 700 / 1000: loss 1.985711
# iteration 800 / 1000: loss 2.003726
# iteration 900 / 1000: loss 1.948076
# Validation accuracy:  0.287

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
#pass
input_size = 32 * 32 * 3
num_classes = 10

best_accuracy = -1
results = {}

hidden_size_list = [150,200]
learningrate_list = [1e-3, 2e-3, 3e-3]
num_of_iter_list = [1000, 1300, 1650, 2000, 2300, 2600]
batchsize_list = [200,400,800]
reg_list = [0.75, 1, 1.2]

for hs in hidden_size_list:
    for bs in batchsize_list:
        for lr in learningrate_list:
            for rs in reg_list:
                print('hs: %d, bs: %d, lr: %f, rs: %f' % (hs,bs,lr,rs))
                new_net= TwoLayerNet(input_size, hs, num_classes)
                new_net.train(X_train, y_train, X_val, y_val, learning_rate=lr, 
                              reg=rs, batch_size=bs, num_iters=1000,verbose = True)
                y_train_pred = new_net.predict(X_train)
                acc_train = np.mean(y_train == y_train_pred)
                y_val_pred = new_net.predict(X_val)
                acc_val = np.mean(y_val == y_val_pred)

                results[(hs, bs, lr,rs)] = (acc_train, acc_val)
                print('hidden_size %d, batch_size %d, lr %f, rs %f: train_accuracy %f val_accuracy %f'
                      % (hs, bs, lr, rs, acc_train, acc_val))
                if best_accuracy < acc_val:
                    best_val = acc_val
                    best_net = new_net
                    best_hs,best_bs,best_lr,best_reg = hs,bs,lr,rs
print('train finish')
print('best_hs %d, best_bs %d, best_lr %f, best_reg %f' % (best_hs, best_bs, best_lr, best_reg))
#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# hs: 150, bs: 200, lr: 0.001000, rs: 0.750000
# iteration 0 / 1000: loss 2.304279
# iteration 100 / 1000: loss 1.835116
# iteration 200 / 1000: loss 1.728102
# iteration 300 / 1000: loss 1.751879
# iteration 400 / 1000: loss 1.713119
# iteration 500 / 1000: loss 1.600739
# iteration 600 / 1000: loss 1.553609
# iteration 700 / 1000: loss 1.446893
# iteration 800 / 1000: loss 1.505764
# iteration 900 / 1000: loss 1.621265
# hidden_size 150, batch_size 200, lr 0.001000, rs 0.750000: train_accuracy 0.491082 val_accuracy 0.470000
# hs: 150, bs: 200, lr: 0.001000, rs: 1.000000
# iteration 0 / 1000: loss 2.304910
# iteration 100 / 1000: loss 1.972220
# iteration 200 / 1000: loss 1.739799
# iteration 300 / 1000: loss 1.718508
# iteration 400 / 1000: loss 1.719251
# iteration 500 / 1000: loss 1.552882
# iteration 600 / 1000: loss 1.538330
# iteration 700 / 1000: loss 1.537026
# iteration 800 / 1000: loss 1.629419
# iteration 900 / 1000: loss 1.585896
# hidden_size 150, batch_size 200, lr 0.001000, rs 1.000000: train_accuracy 0.496633 val_accuracy 0.483000
# hs: 150, bs: 200, lr: 0.001000, rs: 1.200000
# iteration 0 / 1000: loss 2.305420
# iteration 100 / 1000: loss 1.981566
# iteration 200 / 1000: loss 1.802901
# iteration 300 / 1000: loss 1.745259
# iteration 400 / 1000: loss 1.768390
# iteration 500 / 1000: loss 1.702184
# iteration 600 / 1000: loss 1.602836
# iteration 700 / 1000: loss 1.503211
# iteration 800 / 1000: loss 1.687686
# iteration 900 / 1000: loss 1.543722
# hidden_size 150, batch_size 200, lr 0.001000, rs 1.200000: train_accuracy 0.491571 val_accuracy 0.473000
# hs: 150, bs: 200, lr: 0.002000, rs: 0.750000
# iteration 0 / 1000: loss 2.304324
# iteration 100 / 1000: loss 1.778936
# iteration 200 / 1000: loss 1.688417
# iteration 300 / 1000: loss 1.600880
# iteration 400 / 1000: loss 1.786650
# iteration 500 / 1000: loss 1.556598
# iteration 600 / 1000: loss 1.635576
# iteration 700 / 1000: loss 1.538841
# iteration 800 / 1000: loss 1.573005
# iteration 900 / 1000: loss 1.508978
# hidden_size 150, batch_size 200, lr 0.002000, rs 0.750000: train_accuracy 0.503633 val_accuracy 0.490000
# hs: 150, bs: 200, lr: 0.002000, rs: 1.000000
# iteration 0 / 1000: loss 2.304902
# iteration 100 / 1000: loss 1.734372
# iteration 200 / 1000: loss 1.712228
# iteration 300 / 1000: loss 1.497119
# iteration 400 / 1000: loss 1.583891
# iteration 500 / 1000: loss 1.759220
# iteration 600 / 1000: loss 1.549064
# iteration 700 / 1000: loss 1.569091
# iteration 800 / 1000: loss 1.609866
# iteration 900 / 1000: loss 1.680128
# hidden_size 150, batch_size 200, lr 0.002000, rs 1.000000: train_accuracy 0.503429 val_accuracy 0.484000
# hs: 150, bs: 200, lr: 0.002000, rs: 1.200000
# iteration 0 / 1000: loss 2.305398
# iteration 100 / 1000: loss 1.881293
# iteration 200 / 1000: loss 1.779350
# iteration 300 / 1000: loss 1.766387
# iteration 400 / 1000: loss 1.659719
# iteration 500 / 1000: loss 1.622764
# iteration 600 / 1000: loss 1.664993
# iteration 700 / 1000: loss 1.557317
# iteration 800 / 1000: loss 1.563275
# iteration 900 / 1000: loss 1.620033
# hidden_size 150, batch_size 200, lr 0.002000, rs 1.200000: train_accuracy 0.498224 val_accuracy 0.479000
# hs: 150, bs: 200, lr: 0.003000, rs: 0.750000
# iteration 0 / 1000: loss 2.304277
# iteration 100 / 1000: loss 1.864631
# iteration 200 / 1000: loss 1.719297
# iteration 300 / 1000: loss 1.786315
# iteration 400 / 1000: loss 1.631428
# iteration 500 / 1000: loss 1.812025
# iteration 600 / 1000: loss 1.623763
# iteration 700 / 1000: loss 1.810872
# iteration 800 / 1000: loss 1.693511
# iteration 900 / 1000: loss 1.688641
# hidden_size 150, batch_size 200, lr 0.003000, rs 0.750000: train_accuracy 0.466714 val_accuracy 0.445000
# hs: 150, bs: 200, lr: 0.003000, rs: 1.000000
# iteration 0 / 1000: loss 2.304889
# iteration 100 / 1000: loss 1.822134
# iteration 200 / 1000: loss 1.871725
# iteration 300 / 1000: loss 1.616107
# iteration 400 / 1000: loss 1.733917
# iteration 500 / 1000: loss 1.755171
# iteration 600 / 1000: loss 1.702959
# iteration 700 / 1000: loss 1.720274
# iteration 800 / 1000: loss 1.548061
# iteration 900 / 1000: loss 1.629125
# hidden_size 150, batch_size 200, lr 0.003000, rs 1.000000: train_accuracy 0.470347 val_accuracy 0.444000
# hs: 150, bs: 200, lr: 0.003000, rs: 1.200000
# iteration 0 / 1000: loss 2.305299
# iteration 100 / 1000: loss 1.818456
# iteration 200 / 1000: loss 1.774750
# iteration 300 / 1000: loss 1.806622
# iteration 400 / 1000: loss 1.664928
# iteration 500 / 1000: loss 1.859677
# iteration 600 / 1000: loss 1.594076
# iteration 700 / 1000: loss 1.735178
# iteration 800 / 1000: loss 1.831241
# iteration 900 / 1000: loss 1.798750
# hidden_size 150, batch_size 200, lr 0.003000, rs 1.200000: train_accuracy 0.477959 val_accuracy 0.464000
# hs: 150, bs: 400, lr: 0.001000, rs: 0.750000
# iteration 0 / 1000: loss 2.304336
# iteration 100 / 1000: loss 1.913110
# iteration 200 / 1000: loss 1.781501
# iteration 300 / 1000: loss 1.748580
# iteration 400 / 1000: loss 1.690809
# iteration 500 / 1000: loss 1.584412
# iteration 600 / 1000: loss 1.568674
# iteration 700 / 1000: loss 1.573366
# iteration 800 / 1000: loss 1.538328
# iteration 900 / 1000: loss 1.482219
# hidden_size 150, batch_size 400, lr 0.001000, rs 0.750000: train_accuracy 0.512429 val_accuracy 0.486000
# hs: 150, bs: 400, lr: 0.001000, rs: 1.000000
# iteration 0 / 1000: loss 2.304933
# iteration 100 / 1000: loss 1.965388
# iteration 200 / 1000: loss 1.728343
# iteration 300 / 1000: loss 1.742219
# iteration 400 / 1000: loss 1.665351
# iteration 500 / 1000: loss 1.585958
# iteration 600 / 1000: loss 1.571752
# iteration 700 / 1000: loss 1.548241
# iteration 800 / 1000: loss 1.498551
# iteration 900 / 1000: loss 1.558658
# hidden_size 150, batch_size 400, lr 0.001000, rs 1.000000: train_accuracy 0.506367 val_accuracy 0.479000
# hs: 150, bs: 400, lr: 0.001000, rs: 1.200000
# iteration 0 / 1000: loss 2.305364
# iteration 100 / 1000: loss 1.876253
# iteration 200 / 1000: loss 1.707609
# iteration 300 / 1000: loss 1.713536
# iteration 400 / 1000: loss 1.647539
# iteration 500 / 1000: loss 1.519764
# iteration 600 / 1000: loss 1.641432
# iteration 700 / 1000: loss 1.629324
# iteration 800 / 1000: loss 1.633180
# iteration 900 / 1000: loss 1.615641
# hidden_size 150, batch_size 400, lr 0.001000, rs 1.200000: train_accuracy 0.499694 val_accuracy 0.478000
# hs: 150, bs: 400, lr: 0.002000, rs: 0.750000
# iteration 0 / 1000: loss 2.304327
# iteration 100 / 1000: loss 1.731333
# iteration 200 / 1000: loss 1.660144
# iteration 300 / 1000: loss 1.650589
# iteration 400 / 1000: loss 1.590500
# iteration 500 / 1000: loss 1.623697
# iteration 600 / 1000: loss 1.518696
# iteration 700 / 1000: loss 1.508826
# iteration 800 / 1000: loss 1.445604
# iteration 900 / 1000: loss 1.559823
# hidden_size 150, batch_size 400, lr 0.002000, rs 0.750000: train_accuracy 0.482918 val_accuracy 0.457000
# hs: 150, bs: 400, lr: 0.002000, rs: 1.000000
# iteration 0 / 1000: loss 2.304894
# iteration 100 / 1000: loss 1.759549
# iteration 200 / 1000: loss 1.664480
# iteration 300 / 1000: loss 1.589706
# iteration 400 / 1000: loss 1.675862
# iteration 500 / 1000: loss 1.477583
# iteration 600 / 1000: loss 1.555782
# iteration 700 / 1000: loss 1.483252
# iteration 800 / 1000: loss 1.609701
# iteration 900 / 1000: loss 1.520661
# hidden_size 150, batch_size 400, lr 0.002000, rs 1.000000: train_accuracy 0.516551 val_accuracy 0.502000
# hs: 150, bs: 400, lr: 0.002000, rs: 1.200000
# iteration 0 / 1000: loss 2.305349
# iteration 100 / 1000: loss 1.708356
# iteration 200 / 1000: loss 1.776225
# iteration 300 / 1000: loss 1.623495
# iteration 400 / 1000: loss 1.641889
# iteration 500 / 1000: loss 1.582430
# iteration 600 / 1000: loss 1.652277
# iteration 700 / 1000: loss 1.594213
# iteration 800 / 1000: loss 1.529017
# iteration 900 / 1000: loss 1.544570
# hidden_size 150, batch_size 400, lr 0.002000, rs 1.200000: train_accuracy 0.523102 val_accuracy 0.498000
# hs: 150, bs: 400, lr: 0.003000, rs: 0.750000
# iteration 0 / 1000: loss 2.304311
# iteration 100 / 1000: loss 1.680436
# iteration 200 / 1000: loss 1.678594
# iteration 300 / 1000: loss 1.698597
# iteration 400 / 1000: loss 1.574850
# iteration 500 / 1000: loss 1.581059
# iteration 600 / 1000: loss 2.066499
# iteration 700 / 1000: loss 1.552640
# iteration 800 / 1000: loss 1.768544
# iteration 900 / 1000: loss 1.421482
# hidden_size 150, batch_size 400, lr 0.003000, rs 0.750000: train_accuracy 0.492673 val_accuracy 0.462000
# hs: 150, bs: 400, lr: 0.003000, rs: 1.000000
# iteration 0 / 1000: loss 2.304906
# iteration 100 / 1000: loss 1.690457
# iteration 200 / 1000: loss 1.772951
# iteration 300 / 1000: loss 1.762409
# iteration 400 / 1000: loss 1.655512
# iteration 500 / 1000: loss 1.671592
# iteration 600 / 1000: loss 1.713753
# iteration 700 / 1000: loss 1.540827
# iteration 800 / 1000: loss 1.513500
# iteration 900 / 1000: loss 2.310001
# hidden_size 150, batch_size 400, lr 0.003000, rs 1.000000: train_accuracy 0.478082 val_accuracy 0.490000
# hs: 150, bs: 400, lr: 0.003000, rs: 1.200000
# iteration 0 / 1000: loss 2.305367
# iteration 100 / 1000: loss 1.762067
# iteration 200 / 1000: loss 1.808752
# iteration 300 / 1000: loss 1.746172
# iteration 400 / 1000: loss 1.669153
# iteration 500 / 1000: loss 1.873629
# iteration 600 / 1000: loss 1.679990
# iteration 700 / 1000: loss 1.698442
# iteration 800 / 1000: loss 1.614955
# iteration 900 / 1000: loss 1.712362
# hidden_size 150, batch_size 400, lr 0.003000, rs 1.200000: train_accuracy 0.424327 val_accuracy 0.411000
# hs: 150, bs: 800, lr: 0.001000, rs: 0.750000
# iteration 0 / 1000: loss 2.304303
# iteration 100 / 1000: loss 1.915666
# iteration 200 / 1000: loss 1.830557
# iteration 300 / 1000: loss 1.660074
# iteration 400 / 1000: loss 1.578892
# iteration 500 / 1000: loss 1.593520
# iteration 600 / 1000: loss 1.505126
# iteration 700 / 1000: loss 1.542914
# iteration 800 / 1000: loss 1.509355
# iteration 900 / 1000: loss 1.468824
# hidden_size 150, batch_size 800, lr 0.001000, rs 0.750000: train_accuracy 0.520796 val_accuracy 0.492000
# hs: 150, bs: 800, lr: 0.001000, rs: 1.000000
# iteration 0 / 1000: loss 2.304887
# iteration 100 / 1000: loss 1.924780
# iteration 200 / 1000: loss 1.762333
# iteration 300 / 1000: loss 1.666618
# iteration 400 / 1000: loss 1.628696
# iteration 500 / 1000: loss 1.589864
# iteration 600 / 1000: loss 1.568129
# iteration 700 / 1000: loss 1.594657
# iteration 800 / 1000: loss 1.531085
# iteration 900 / 1000: loss 1.496882
# hidden_size 150, batch_size 800, lr 0.001000, rs 1.000000: train_accuracy 0.516816 val_accuracy 0.490000
# hs: 150, bs: 800, lr: 0.001000, rs: 1.200000
# iteration 0 / 1000: loss 2.305343
# iteration 100 / 1000: loss 1.909670
# iteration 200 / 1000: loss 1.767544
# iteration 300 / 1000: loss 1.664430
# iteration 400 / 1000: loss 1.663951
# iteration 500 / 1000: loss 1.675133
# iteration 600 / 1000: loss 1.623990
# iteration 700 / 1000: loss 1.544243
# iteration 800 / 1000: loss 1.592849
# iteration 900 / 1000: loss 1.591818
# hidden_size 150, batch_size 800, lr 0.001000, rs 1.200000: train_accuracy 0.507429 val_accuracy 0.473000
# hs: 150, bs: 800, lr: 0.002000, rs: 0.750000
# iteration 0 / 1000: loss 2.304322
# iteration 100 / 1000: loss 1.749186
# iteration 200 / 1000: loss 1.605213
# iteration 300 / 1000: loss 1.536176
# iteration 400 / 1000: loss 1.562881
# iteration 500 / 1000: loss 1.493423
# iteration 600 / 1000: loss 1.511482
# iteration 700 / 1000: loss 1.461447
# iteration 800 / 1000: loss 1.452948
# iteration 900 / 1000: loss 1.549214
# hidden_size 150, batch_size 800, lr 0.002000, rs 0.750000: train_accuracy 0.540735 val_accuracy 0.498000
# hs: 150, bs: 800, lr: 0.002000, rs: 1.000000
# iteration 0 / 1000: loss 2.304874
# iteration 100 / 1000: loss 1.737970
# iteration 200 / 1000: loss 1.591274
# iteration 300 / 1000: loss 1.615264
# iteration 400 / 1000: loss 1.607653
# iteration 500 / 1000: loss 1.515141
# iteration 600 / 1000: loss 1.595604
# iteration 700 / 1000: loss 1.509269
# iteration 800 / 1000: loss 1.476307
# iteration 900 / 1000: loss 1.475270
# hidden_size 150, batch_size 800, lr 0.002000, rs 1.000000: train_accuracy 0.511571 val_accuracy 0.482000
# hs: 150, bs: 800, lr: 0.002000, rs: 1.200000
# iteration 0 / 1000: loss 2.305377
# iteration 100 / 1000: loss 1.744030
# iteration 200 / 1000: loss 1.652334
# iteration 300 / 1000: loss 1.560245
# iteration 400 / 1000: loss 1.572392
# iteration 500 / 1000: loss 1.548910
# iteration 600 / 1000: loss 1.534960
# iteration 700 / 1000: loss 1.549575
# iteration 800 / 1000: loss 1.562874
# iteration 900 / 1000: loss 1.553142
# hidden_size 150, batch_size 800, lr 0.002000, rs 1.200000: train_accuracy 0.530694 val_accuracy 0.509000
# hs: 150, bs: 800, lr: 0.003000, rs: 0.750000
# iteration 0 / 1000: loss 2.304297
# iteration 100 / 1000: loss 1.745240
# iteration 200 / 1000: loss 1.697396
# iteration 300 / 1000: loss 1.570136
# iteration 400 / 1000: loss 1.579569
# iteration 500 / 1000: loss 1.615105
# iteration 600 / 1000: loss 1.488839
# iteration 700 / 1000: loss 1.475979
# iteration 800 / 1000: loss 1.503398
# iteration 900 / 1000: loss 1.617104
# hidden_size 150, batch_size 800, lr 0.003000, rs 0.750000: train_accuracy 0.532408 val_accuracy 0.500000
# hs: 150, bs: 800, lr: 0.003000, rs: 1.000000
# iteration 0 / 1000: loss 2.304889
# iteration 100 / 1000: loss 1.719376
# iteration 200 / 1000: loss 1.667175
# iteration 300 / 1000: loss 1.761918
# iteration 400 / 1000: loss 1.695674
# iteration 500 / 1000: loss 1.646049
# iteration 600 / 1000: loss 1.528726
# iteration 700 / 1000: loss 1.507995
# iteration 800 / 1000: loss 1.541774
# iteration 900 / 1000: loss 2.420660
# hidden_size 150, batch_size 800, lr 0.003000, rs 1.000000: train_accuracy 0.528592 val_accuracy 0.503000
# hs: 150, bs: 800, lr: 0.003000, rs: 1.200000
# iteration 0 / 1000: loss 2.305313
# iteration 100 / 1000: loss 1.722099
# iteration 200 / 1000: loss 1.681713
# iteration 300 / 1000: loss 1.662549
# iteration 400 / 1000: loss 1.665687
# iteration 500 / 1000: loss 1.612402
# iteration 600 / 1000: loss 1.549073
# iteration 700 / 1000: loss 1.715768
# iteration 800 / 1000: loss 1.580391
# iteration 900 / 1000: loss 1.554334
# hidden_size 150, batch_size 800, lr 0.003000, rs 1.200000: train_accuracy 0.510694 val_accuracy 0.472000
# hs: 200, bs: 200, lr: 0.001000, rs: 0.750000
# iteration 0 / 1000: loss 2.304877
# iteration 100 / 1000: loss 1.925121
# iteration 200 / 1000: loss 1.798355
# iteration 300 / 1000: loss 1.775753
# iteration 400 / 1000: loss 1.592468
# iteration 500 / 1000: loss 1.676130
# iteration 600 / 1000: loss 1.663760
# iteration 700 / 1000: loss 1.475144
# iteration 800 / 1000: loss 1.544004
# iteration 900 / 1000: loss 1.602480
# hidden_size 200, batch_size 200, lr 0.001000, rs 0.750000: train_accuracy 0.502714 val_accuracy 0.470000
# hs: 200, bs: 200, lr: 0.001000, rs: 1.000000
# iteration 0 / 1000: loss 2.305666
# iteration 100 / 1000: loss 2.029770
# iteration 200 / 1000: loss 1.785892
# iteration 300 / 1000: loss 1.666552
# iteration 400 / 1000: loss 1.662312
# iteration 500 / 1000: loss 1.802278
# iteration 600 / 1000: loss 1.761525
# iteration 700 / 1000: loss 1.543052
# iteration 800 / 1000: loss 1.552554
# iteration 900 / 1000: loss 1.743799
# hidden_size 200, batch_size 200, lr 0.001000, rs 1.000000: train_accuracy 0.497653 val_accuracy 0.481000
# hs: 200, bs: 200, lr: 0.001000, rs: 1.200000
# iteration 0 / 1000: loss 2.306264
# iteration 100 / 1000: loss 1.997554
# iteration 200 / 1000: loss 1.857565
# iteration 300 / 1000: loss 1.788099
# iteration 400 / 1000: loss 1.558322
# iteration 500 / 1000: loss 1.617569
# iteration 600 / 1000: loss 1.520751
# iteration 700 / 1000: loss 1.659530
# iteration 800 / 1000: loss 1.587904
# iteration 900 / 1000: loss 1.562304
# hidden_size 200, batch_size 200, lr 0.001000, rs 1.200000: train_accuracy 0.490306 val_accuracy 0.465000
# hs: 200, bs: 200, lr: 0.002000, rs: 0.750000
# iteration 0 / 1000: loss 2.304864
# iteration 100 / 1000: loss 1.835158
# iteration 200 / 1000: loss 1.674476
# iteration 300 / 1000: loss 1.819857
# iteration 400 / 1000: loss 1.551584
# iteration 500 / 1000: loss 1.572574
# iteration 600 / 1000: loss 1.679619
# iteration 700 / 1000: loss 1.420666
# iteration 800 / 1000: loss 1.541137
# iteration 900 / 1000: loss 1.514623
# hidden_size 200, batch_size 200, lr 0.002000, rs 0.750000: train_accuracy 0.519061 val_accuracy 0.500000
# hs: 200, bs: 200, lr: 0.002000, rs: 1.000000
# iteration 0 / 1000: loss 2.305663
# iteration 100 / 1000: loss 1.878379
# iteration 200 / 1000: loss 1.785961
# iteration 300 / 1000: loss 1.670294
# iteration 400 / 1000: loss 1.583958
# iteration 500 / 1000: loss 1.601469
# iteration 600 / 1000: loss 1.730530
# iteration 700 / 1000: loss 1.661340
# iteration 800 / 1000: loss 1.490156
# iteration 900 / 1000: loss 1.607676
# hidden_size 200, batch_size 200, lr 0.002000, rs 1.000000: train_accuracy 0.495816 val_accuracy 0.468000
# hs: 200, bs: 200, lr: 0.002000, rs: 1.200000
# iteration 0 / 1000: loss 2.306291
# iteration 100 / 1000: loss 1.804146
# iteration 200 / 1000: loss 1.761920
# iteration 300 / 1000: loss 1.806472
# iteration 400 / 1000: loss 1.681755
# iteration 500 / 1000: loss 1.658442
# iteration 600 / 1000: loss 1.650885
# iteration 700 / 1000: loss 1.690681
# iteration 800 / 1000: loss 1.629535
# iteration 900 / 1000: loss 1.610171
# hidden_size 200, batch_size 200, lr 0.002000, rs 1.200000: train_accuracy 0.492959 val_accuracy 0.473000
# hs: 200, bs: 200, lr: 0.003000, rs: 0.750000
# iteration 0 / 1000: loss 2.304838
# iteration 100 / 1000: loss 1.881270
# iteration 200 / 1000: loss 1.813955
# iteration 300 / 1000: loss 1.800909
# iteration 400 / 1000: loss 1.767400
# iteration 500 / 1000: loss 1.554467
# iteration 600 / 1000: loss 1.769648
# iteration 700 / 1000: loss 1.720142
# iteration 800 / 1000: loss 1.894092
# iteration 900 / 1000: loss 1.753341
# hidden_size 200, batch_size 200, lr 0.003000, rs 0.750000: train_accuracy 0.482041 val_accuracy 0.475000
# hs: 200, bs: 200, lr: 0.003000, rs: 1.000000
# iteration 0 / 1000: loss 2.305586
# iteration 100 / 1000: loss 1.846812
# iteration 200 / 1000: loss 1.722428
# iteration 300 / 1000: loss 1.690926
# iteration 400 / 1000: loss 1.646128
# iteration 500 / 1000: loss 1.772368
# iteration 600 / 1000: loss 1.597995
# iteration 700 / 1000: loss 1.598823
# iteration 800 / 1000: loss 1.885977
# iteration 900 / 1000: loss 1.579961
# hidden_size 200, batch_size 200, lr 0.003000, rs 1.000000: train_accuracy 0.454980 val_accuracy 0.451000
# hs: 200, bs: 200, lr: 0.003000, rs: 1.200000
# iteration 0 / 1000: loss 2.306218
# iteration 100 / 1000: loss 1.890572
# iteration 200 / 1000: loss 1.651097
# iteration 300 / 1000: loss 1.786353
# iteration 400 / 1000: loss 1.946461
# iteration 500 / 1000: loss 1.761927
# iteration 600 / 1000: loss 1.859242
# iteration 700 / 1000: loss 1.671031
# iteration 800 / 1000: loss 1.758687
# iteration 900 / 1000: loss 1.947234
# hidden_size 200, batch_size 200, lr 0.003000, rs 1.200000: train_accuracy 0.449020 val_accuracy 0.439000
# hs: 200, bs: 400, lr: 0.001000, rs: 0.750000
# iteration 0 / 1000: loss 2.304900
# iteration 100 / 1000: loss 1.893246
# iteration 200 / 1000: loss 1.779202
# iteration 300 / 1000: loss 1.678041
# iteration 400 / 1000: loss 1.690584
# iteration 500 / 1000: loss 1.577405
# iteration 600 / 1000: loss 1.522290
# iteration 700 / 1000: loss 1.509731
# iteration 800 / 1000: loss 1.458050
# iteration 900 / 1000: loss 1.453408
# hidden_size 200, batch_size 400, lr 0.001000, rs 0.750000: train_accuracy 0.520735 val_accuracy 0.495000
# hs: 200, bs: 400, lr: 0.001000, rs: 1.000000
# iteration 0 / 1000: loss 2.305671
# iteration 100 / 1000: loss 1.888490
# iteration 200 / 1000: loss 1.775019
# iteration 300 / 1000: loss 1.655973
# iteration 400 / 1000: loss 1.642177
# iteration 500 / 1000: loss 1.678876
# iteration 600 / 1000: loss 1.629301
# iteration 700 / 1000: loss 1.566986
# iteration 800 / 1000: loss 1.516884
# iteration 900 / 1000: loss 1.600665
# hidden_size 200, batch_size 400, lr 0.001000, rs 1.000000: train_accuracy 0.509959 val_accuracy 0.494000
# hs: 200, bs: 400, lr: 0.001000, rs: 1.200000
# iteration 0 / 1000: loss 2.306276
# iteration 100 / 1000: loss 1.919409
# iteration 200 / 1000: loss 1.689828
# iteration 300 / 1000: loss 1.701408
# iteration 400 / 1000: loss 1.674776
# iteration 500 / 1000: loss 1.548597
# iteration 600 / 1000: loss 1.630125
# iteration 700 / 1000: loss 1.552949
# iteration 800 / 1000: loss 1.628187
# iteration 900 / 1000: loss 1.579322
# hidden_size 200, batch_size 400, lr 0.001000, rs 1.200000: train_accuracy 0.505857 val_accuracy 0.483000
# hs: 200, bs: 400, lr: 0.002000, rs: 0.750000
# iteration 0 / 1000: loss 2.304937
# iteration 100 / 1000: loss 1.842118
# iteration 200 / 1000: loss 1.609705
# iteration 300 / 1000: loss 1.606097
# iteration 400 / 1000: loss 1.579309
# iteration 500 / 1000: loss 1.531544
# iteration 600 / 1000: loss 1.446474
# iteration 700 / 1000: loss 1.694035
# iteration 800 / 1000: loss 1.491814
# iteration 900 / 1000: loss 1.401558
# hidden_size 200, batch_size 400, lr 0.002000, rs 0.750000: train_accuracy 0.526939 val_accuracy 0.495000
# hs: 200, bs: 400, lr: 0.002000, rs: 1.000000
# iteration 0 / 1000: loss 2.305621
# iteration 100 / 1000: loss 1.772215
# iteration 200 / 1000: loss 1.695439
# iteration 300 / 1000: loss 1.743143
# iteration 400 / 1000: loss 1.650198
# iteration 500 / 1000: loss 1.493459
# iteration 600 / 1000: loss 1.561796
# iteration 700 / 1000: loss 1.557466
# iteration 800 / 1000: loss 1.553977
# iteration 900 / 1000: loss 1.537583
# hidden_size 200, batch_size 400, lr 0.002000, rs 1.000000: train_accuracy 0.533122 val_accuracy 0.494000
# hs: 200, bs: 400, lr: 0.002000, rs: 1.200000
# iteration 0 / 1000: loss 2.306260
# iteration 100 / 1000: loss 1.858606
# iteration 200 / 1000: loss 1.725203
# iteration 300 / 1000: loss 1.616806
# iteration 400 / 1000: loss 1.633639
# iteration 500 / 1000: loss 1.600611
# iteration 600 / 1000: loss 1.660773
# iteration 700 / 1000: loss 1.509965
# iteration 800 / 1000: loss 1.579765
# iteration 900 / 1000: loss 1.553305
# hidden_size 200, batch_size 400, lr 0.002000, rs 1.200000: train_accuracy 0.518878 val_accuracy 0.497000
# hs: 200, bs: 400, lr: 0.003000, rs: 0.750000
# iteration 0 / 1000: loss 2.304925
# iteration 100 / 1000: loss 1.836094
# iteration 200 / 1000: loss 1.624888
# iteration 300 / 1000: loss 1.915027
# iteration 400 / 1000: loss 1.540828
# iteration 500 / 1000: loss 1.580230
# iteration 600 / 1000: loss 1.703056
# iteration 700 / 1000: loss 1.732237
# iteration 800 / 1000: loss 1.542750
# iteration 900 / 1000: loss 1.727615
# hidden_size 200, batch_size 400, lr 0.003000, rs 0.750000: train_accuracy 0.521612 val_accuracy 0.498000
# hs: 200, bs: 400, lr: 0.003000, rs: 1.000000
# iteration 0 / 1000: loss 2.305709
# iteration 100 / 1000: loss 1.788110
# iteration 200 / 1000: loss 1.652621
# iteration 300 / 1000: loss 1.593288
# iteration 400 / 1000: loss 1.559224
# iteration 500 / 1000: loss 1.633956
# iteration 600 / 1000: loss 1.602966
# iteration 700 / 1000: loss 1.659043
# iteration 800 / 1000: loss 1.664801
# iteration 900 / 1000: loss 1.529805
# hidden_size 200, batch_size 400, lr 0.003000, rs 1.000000: train_accuracy 0.479408 val_accuracy 0.447000
# hs: 200, bs: 400, lr: 0.003000, rs: 1.200000
# iteration 0 / 1000: loss 2.306260
# iteration 100 / 1000: loss 1.868202
# iteration 200 / 1000: loss 1.664444
# iteration 300 / 1000: loss 1.805995
# iteration 400 / 1000: loss 1.676586
# iteration 500 / 1000: loss 1.729121
# iteration 600 / 1000: loss 1.731536
# iteration 700 / 1000: loss 1.686730
# iteration 800 / 1000: loss 1.652770
# iteration 900 / 1000: loss 1.633252
# hidden_size 200, batch_size 400, lr 0.003000, rs 1.200000: train_accuracy 0.471837 val_accuracy 0.444000
# hs: 200, bs: 800, lr: 0.001000, rs: 0.750000
# iteration 0 / 1000: loss 2.304919
# iteration 100 / 1000: loss 1.962391
# iteration 200 / 1000: loss 1.776952
# iteration 300 / 1000: loss 1.686268
# iteration 400 / 1000: loss 1.566147
# iteration 500 / 1000: loss 1.590359
# iteration 600 / 1000: loss 1.611251
# iteration 700 / 1000: loss 1.547368
# iteration 800 / 1000: loss 1.510319
# iteration 900 / 1000: loss 1.422713
# hidden_size 200, batch_size 800, lr 0.001000, rs 0.750000: train_accuracy 0.523082 val_accuracy 0.483000
# hs: 200, bs: 800, lr: 0.001000, rs: 1.000000
# iteration 0 / 1000: loss 2.305701
# iteration 100 / 1000: loss 1.904442
# iteration 200 / 1000: loss 1.747270
# iteration 300 / 1000: loss 1.702170
# iteration 400 / 1000: loss 1.569117
# iteration 500 / 1000: loss 1.590944
# iteration 600 / 1000: loss 1.553700
# iteration 700 / 1000: loss 1.581333
# iteration 800 / 1000: loss 1.488216
# iteration 900 / 1000: loss 1.457504
# hidden_size 200, batch_size 800, lr 0.001000, rs 1.000000: train_accuracy 0.513347 val_accuracy 0.491000
# hs: 200, bs: 800, lr: 0.001000, rs: 1.200000
# iteration 0 / 1000: loss 2.306304
# iteration 100 / 1000: loss 1.946724
# iteration 200 / 1000: loss 1.738188
# iteration 300 / 1000: loss 1.706213
# iteration 400 / 1000: loss 1.610926
# iteration 500 / 1000: loss 1.644115
# iteration 600 / 1000: loss 1.593597
# iteration 700 / 1000: loss 1.613297
# iteration 800 / 1000: loss 1.493434
# iteration 900 / 1000: loss 1.519050
# hidden_size 200, batch_size 800, lr 0.001000, rs 1.200000: train_accuracy 0.511735 val_accuracy 0.494000
# hs: 200, bs: 800, lr: 0.002000, rs: 0.750000
# iteration 0 / 1000: loss 2.304914
# iteration 100 / 1000: loss 1.754804
# iteration 200 / 1000: loss 1.696019
# iteration 300 / 1000: loss 1.576362
# iteration 400 / 1000: loss 1.559863
# iteration 500 / 1000: loss 1.511790
# iteration 600 / 1000: loss 1.502114
# iteration 700 / 1000: loss 1.550199
# iteration 800 / 1000: loss 1.538535
# iteration 900 / 1000: loss 1.485551
# hidden_size 200, batch_size 800, lr 0.002000, rs 0.750000: train_accuracy 0.546918 val_accuracy 0.507000
# hs: 200, bs: 800, lr: 0.002000, rs: 1.000000
# iteration 0 / 1000: loss 2.305635
# iteration 100 / 1000: loss 1.759742
# iteration 200 / 1000: loss 1.696659
# iteration 300 / 1000: loss 1.620314
# iteration 400 / 1000: loss 1.532784
# iteration 500 / 1000: loss 1.598489
# iteration 600 / 1000: loss 1.606933
# iteration 700 / 1000: loss 1.515801
# iteration 800 / 1000: loss 1.524617
# iteration 900 / 1000: loss 1.454005
# hidden_size 200, batch_size 800, lr 0.002000, rs 1.000000: train_accuracy 0.533265 val_accuracy 0.505000
# hs: 200, bs: 800, lr: 0.002000, rs: 1.200000
# iteration 0 / 1000: loss 2.306296
# iteration 100 / 1000: loss 1.823288
# iteration 200 / 1000: loss 1.652506
# iteration 300 / 1000: loss 1.594333
# iteration 400 / 1000: loss 1.699761
# iteration 500 / 1000: loss 1.511977
# iteration 600 / 1000: loss 1.600012
# iteration 700 / 1000: loss 1.612884
# iteration 800 / 1000: loss 1.447720
# iteration 900 / 1000: loss 1.484898
# hidden_size 200, batch_size 800, lr 0.002000, rs 1.200000: train_accuracy 0.538143 val_accuracy 0.496000
# hs: 200, bs: 800, lr: 0.003000, rs: 0.750000
# iteration 0 / 1000: loss 2.304874
# iteration 100 / 1000: loss 1.693971
# iteration 200 / 1000: loss 1.686042
# iteration 300 / 1000: loss 1.627238
# iteration 400 / 1000: loss 1.636854
# iteration 500 / 1000: loss 1.634232
# iteration 600 / 1000: loss 1.658760
# iteration 700 / 1000: loss 1.526931
# iteration 800 / 1000: loss 1.809230
# iteration 900 / 1000: loss 1.517017
# hidden_size 200, batch_size 800, lr 0.003000, rs 0.750000: train_accuracy 0.502469 val_accuracy 0.427000
# hs: 200, bs: 800, lr: 0.003000, rs: 1.000000
# iteration 0 / 1000: loss 2.305635
# iteration 100 / 1000: loss 1.819710
# iteration 200 / 1000: loss 1.688909
# iteration 300 / 1000: loss 1.495058
# iteration 400 / 1000: loss 1.647858
# iteration 500 / 1000: loss 1.575655
# iteration 600 / 1000: loss 1.554007
# iteration 700 / 1000: loss 1.666943
# iteration 800 / 1000: loss 1.535741
# iteration 900 / 1000: loss 1.544944
# hidden_size 200, batch_size 800, lr 0.003000, rs 1.000000: train_accuracy 0.501102 val_accuracy 0.480000
# hs: 200, bs: 800, lr: 0.003000, rs: 1.200000
# iteration 0 / 1000: loss 2.306253
# iteration 100 / 1000: loss 1.751870
# iteration 200 / 1000: loss 1.668309
# iteration 300 / 1000: loss 1.680312
# iteration 400 / 1000: loss 1.663070
# iteration 500 / 1000: loss 1.639042
# iteration 600 / 1000: loss 1.853514
# iteration 700 / 1000: loss 1.559363
# iteration 800 / 1000: loss 1.607666
# iteration 900 / 1000: loss 1.607059
# hidden_size 200, batch_size 800, lr 0.003000, rs 1.200000: train_accuracy 0.516469 val_accuracy 0.491000
# train finish
# best_hs 200, best_bs 800, best_lr 0.003000, best_reg 1.200000

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.488
